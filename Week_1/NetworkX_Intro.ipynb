# %%
import networkx as nx

# %%
my_graph = nx.Graph()

# %%
my_graph.add_node('Daryl')

# %%
my_graph.add_nodes_from(['Katie','Izzy','Skye'])

# %%
my_graph.add_edge('Daryl','Katie')

# %%
my_graph.add_edges_from([('Skye','Katie'),('Daryl', 'Izzy'),('Izzy','Skye')])

# %%
nx.draw(my_graph,with_labels=True, node_size=1500,node_col)
